# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
import numpy as np

# %%
olympic= pd.read_csv(r"C:\Users\sileo\Downloads\Hackathon_4.0_Summar_OlympicData\Olympic.csv",encoding = 'latin1')
olympic
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# 1           KOSENKOV, Aleksandr    Men          URS   Soviet Union
# 2          BOGGS, Philip George    Men          USA  United States
# 3      CAGNOTTO, Giorgio Franco    Men          ITA          Italy
# 4        WILSON, Deborah Keplar  Women          USA  United States
# ...                         ...    ...          ...            ...
# 15428        GUENOT, Christophe    Men          FRA         France
# 15429       KVIRKELIA, Manuchar    Men          GEO        Georgia
# 15430          RAHIMOV, Vitaliy    Men          AZE     Azerbaijan
# 15431            GUENOT, Steeve    Men          FRA         France
# 15432             LOPEZ, Mijain    Men          CUB           Cuba
#
#       Event_gender   Medal
# 0                W  Silver
# 1                M  Bronze
# 2                M    Gold
# 3                M  Silver
# 4                W  Bronze
# ...            ...     ...
# 15428            M  Bronze
# 15429            M    Gold
# 15430            M  Silver
# 15431            M    Gold
# 15432            M    Gold
#
# [15433 rows x 11 columns]

# %%
olympic.shape
# Out:
# (15433, 11)

# %%
olympic.size
# Out:
# 169763

# %%
len(olympic)
# Out:
# 15433

# %%
olympic.columns
# Out:
# Index(['City', 'Year', 'Sport', 'Discipline', 'Event', 'Athlete', 'Gender',
#        'Country_Code', 'Country', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15433 entries, 0 to 15432
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          15316 non-null  object
#  1   Year          15316 non-null  float64
#  2   Sport         15316 non-null  object
#  3   Discipline    15316 non-null  object
#  4   Event         15316 non-null  object
#  5   Athlete       15316 non-null  object
#  6   Gender        15316 non-null  object
#  7   Country_Code  15316 non-null  object
#  8   Country       15316 non-null  object
#  9   Event_gender  15316 non-null  object
#  10  Medal         15316 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 1.3+ MB

# %%
olympic.dtypes
# Out:
# City             object
# Year            float64
# Sport            object
# Discipline       object
# Event            object
# Athlete          object
# Gender           object
# Country_Code     object
# Country          object
# Event_gender     object
# Medal            object
# dtype: object

# %%
olympic.describe()
# Out:
#                Year
# count  15316.000000
# mean    1993.620789
# std       10.159851
# min     1976.000000
# 25%     1984.000000
# 50%     1996.000000
# 75%     2004.000000
# max     2008.000000

# %%
olympic.isnull()
# Out:
#         City   Year  Sport  Discipline  Event  Athlete  Gender  Country_Code  \
# 0      False  False  False       False  False    False   False         False
# 1      False  False  False       False  False    False   False         False
# 2      False  False  False       False  False    False   False         False
# 3      False  False  False       False  False    False   False         False
# 4      False  False  False       False  False    False   False         False
# ...      ...    ...    ...         ...    ...      ...     ...           ...
# 15428  False  False  False       False  False    False   False         False
# 15429  False  False  False       False  False    False   False         False
# 15430  False  False  False       False  False    False   False         False
# 15431  False  False  False       False  False    False   False         False
# 15432  False  False  False       False  False    False   False         False
#
#        Country  Event_gender  Medal
# 0        False         False  False
# 1        False         False  False
# 2        False         False  False
# 3        False         False  False
# 4        False         False  False
# ...        ...           ...    ...
# 15428    False         False  False
# 15429    False         False  False
# 15430    False         False  False
# 15431    False         False  False
# 15432    False         False  False
#
# [15433 rows x 11 columns]

# %%
olympic.isna()
# Out:
#         City   Year  Sport  Discipline  Event  Athlete  Gender  Country_Code  \
# 0      False  False  False       False  False    False   False         False
# 1      False  False  False       False  False    False   False         False
# 2      False  False  False       False  False    False   False         False
# 3      False  False  False       False  False    False   False         False
# 4      False  False  False       False  False    False   False         False
# ...      ...    ...    ...         ...    ...      ...     ...           ...
# 15428  False  False  False       False  False    False   False         False
# 15429  False  False  False       False  False    False   False         False
# 15430  False  False  False       False  False    False   False         False
# 15431  False  False  False       False  False    False   False         False
# 15432  False  False  False       False  False    False   False         False
#
#        Country  Event_gender  Medal
# 0        False         False  False
# 1        False         False  False
# 2        False         False  False
# 3        False         False  False
# 4        False         False  False
# ...        ...           ...    ...
# 15428    False         False  False
# 15429    False         False  False
# 15430    False         False  False
# 15431    False         False  False
# 15432    False         False  False
#
# [15433 rows x 11 columns]

# %%
olympic.head(5)
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
olympic.tail(5)
# Out:
#           City    Year      Sport       Discipline       Event  \
# 15428  Beijing  2008.0  Wrestling  Wrestling Gre-R   66 - 74kg
# 15429  Beijing  2008.0  Wrestling  Wrestling Gre-R   66 - 74kg
# 15430  Beijing  2008.0  Wrestling  Wrestling Gre-R   55 - 60kg
# 15431  Beijing  2008.0  Wrestling  Wrestling Gre-R   60 - 66kg
# 15432  Beijing  2008.0  Wrestling  Wrestling Gre-R  96 - 120kg
#
#                    Athlete Gender Country_Code     Country Event_gender  \
# 15428   GUENOT, Christophe    Men          FRA      France            M
# 15429  KVIRKELIA, Manuchar    Men          GEO     Georgia            M
# 15430     RAHIMOV, Vitaliy    Men          AZE  Azerbaijan            M
# 15431       GUENOT, Steeve    Men          FRA      France            M
# 15432        LOPEZ, Mijain    Men          CUB        Cuba            M
#
#         Medal
# 15428  Bronze
# 15429    Gold
# 15430  Silver
# 15431    Gold
# 15432    Gold

# %%
olympic.isna().count()
# Out:
# City            15433
# Year            15433
# Sport           15433
# Discipline      15433
# Event           15433
# Athlete         15433
# Gender          15433
# Country_Code    15433
# Country         15433
# Event_gender    15433
# Medal           15433
# dtype: int64

# %%
olympic.isna().sum()
# Out:
# City            117
# Year            117
# Sport           117
# Discipline      117
# Event           117
# Athlete         117
# Gender          117
# Country_Code    117
# Country         117
# Event_gender    117
# Medal           117
# dtype: int64

# %%
olympic.isnull().sum()
# Out:
# City            117
# Year            117
# Sport           117
# Discipline      117
# Event           117
# Athlete         117
# Gender          117
# Country_Code    117
# Country         117
# Event_gender    117
# Medal           117
# dtype: int64

# %%
olympic.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15428    False
# 15429    False
# 15430    False
# 15431    False
# 15432    False
# Length: 15433, dtype: bool

# %%
olympic.duplicated().sum()
# Out:
# 117

# %%
olympic1 = olympic.drop_duplicates()
olympic1
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# 1           KOSENKOV, Aleksandr    Men          URS   Soviet Union
# 2          BOGGS, Philip George    Men          USA  United States
# 3      CAGNOTTO, Giorgio Franco    Men          ITA          Italy
# 4        WILSON, Deborah Keplar  Women          USA  United States
# ...                         ...    ...          ...            ...
# 15428        GUENOT, Christophe    Men          FRA         France
# 15429       KVIRKELIA, Manuchar    Men          GEO        Georgia
# 15430          RAHIMOV, Vitaliy    Men          AZE     Azerbaijan
# 15431            GUENOT, Steeve    Men          FRA         France
# 15432             LOPEZ, Mijain    Men          CUB           Cuba
#
#       Event_gender   Medal
# 0                W  Silver
# 1                M  Bronze
# 2                M    Gold
# 3                M  Silver
# 4                W  Bronze
# ...            ...     ...
# 15428            M  Bronze
# 15429            M    Gold
# 15430            M  Silver
# 15431            M    Gold
# 15432            M    Gold
#
# [15316 rows x 11 columns]

# %%
olympic1.duplicated().sum()
# Out:
# 0

# %%
olympic1["Athlete"].str.title()
# Out:
# 0                 Köhler, Christa
# 1             Kosenkov, Aleksandr
# 2            Boggs, Philip George
# 3        Cagnotto, Giorgio Franco
# 4          Wilson, Deborah Keplar
#                    ...
# 15428          Guenot, Christophe
# 15429         Kvirkelia, Manuchar
# 15430            Rahimov, Vitaliy
# 15431              Guenot, Steeve
# 15432               Lopez, Mijain
# Name: Athlete, Length: 15316, dtype: object

# %%
#olympic1 = olympic1["Athlete"].str.title()
olympic1
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# 1           KOSENKOV, Aleksandr    Men          URS   Soviet Union
# 2          BOGGS, Philip George    Men          USA  United States
# 3      CAGNOTTO, Giorgio Franco    Men          ITA          Italy
# 4        WILSON, Deborah Keplar  Women          USA  United States
# ...                         ...    ...          ...            ...
# 15428        GUENOT, Christophe    Men          FRA         France
# 15429       KVIRKELIA, Manuchar    Men          GEO        Georgia
# 15430          RAHIMOV, Vitaliy    Men          AZE     Azerbaijan
# 15431            GUENOT, Steeve    Men          FRA         France
# 15432             LOPEZ, Mijain    Men          CUB           Cuba
#
#       Event_gender   Medal
# 0                W  Silver
# 1                M  Bronze
# 2                M    Gold
# 3                M  Silver
# 4                W  Bronze
# ...            ...     ...
# 15428            M  Bronze
# 15429            M    Gold
# 15430            M  Silver
# 15431            M    Gold
# 15432            M    Gold
#
# [15316 rows x 11 columns]

# %%
df1 =olympic1[["City","Year","Medal"]]
df1
# Out:
#            City    Year   Medal
# 0      Montreal  1976.0  Silver
# 1      Montreal  1976.0  Bronze
# 2      Montreal  1976.0    Gold
# 3      Montreal  1976.0  Silver
# 4      Montreal  1976.0  Bronze
# ...         ...     ...     ...
# 15428   Beijing  2008.0  Bronze
# 15429   Beijing  2008.0    Gold
# 15430   Beijing  2008.0  Silver
# 15431   Beijing  2008.0    Gold
# 15432   Beijing  2008.0    Gold
#
# [15316 rows x 3 columns]

# %%
c1 =df1.groupby(["City"]).count()
fig,ax =plt.subplots(figsize=(8,8))
plt.plot(c1, marker="o",color="blue")
# Out:
# [<matplotlib.lines.Line2D at 0x2175df00b00>,
#  <matplotlib.lines.Line2D at 0x2175e021520>]

# %%
c1 =df1.groupby(["Year"]).count()
fig,ax =plt.subplots(figsize=(5,5))
plt.plot(c1, marker="s")
# Out:
# [<matplotlib.lines.Line2D at 0x2175e32a450>,
#  <matplotlib.lines.Line2D at 0x2175e367a10>]

# %%
Total_Medals= olympic1["Medal"].count()
Total_Medals
# Out:
# 15315

# %%
Count_medals = olympic1["Medal"].value_counts()
Count_medals
# Out:
# Medal
# Bronze    5258
# Gold      5041
# Silver    5016
# Name: count, dtype: int64

# %%
count_nations = olympic1["Country"].value_counts()
count_nations
# Out:
# Country
# United States      1992
# Soviet Union       1021
# Australia           798
# Germany             691
# China               679
#                    ...
# Cote d'Ivoire         1
# Djibouti              1
# Senegal               1
# Virgin Islands*       1
# Afghanistan           1
# Name: count, Length: 127, dtype: int64

# %%
country = olympic1["Country"].unique()

# %%
[[olympic1.groupby(["Country","Sport"]).value_counts()]]
# Out:
# [[Country      Sport      City       Year    Discipline  Event    Athlete                 Gender  Country_Code  Event_gender  Medal
#   Afghanistan  Taekwondo  Beijing    2008.0  Taekwondo   - 58 kg  NIKPAI, Rohullah        Men     AFG           M             Bronze    1
#   Algeria      Athletics  Atlanta    1996.0  Athletics   1500m    MORCELI, Nourredine     Men     ALG           M             Gold      1
#                           Barcelona  1992.0  Athletics   1500m    BOULMERKA, Hassiba      Women   ALG           W             Gold      1
#                           Sydney     2000.0  Athletics   1500m    MERAH-BENIDA, Nouria    Women   ALG           W             Gold      1
#                                                          5000m    SAIDI-SIEF, Ali         Men     ALG           M             Silver    1
#                                                                                                                                        ..
#   Zimbabwe     Hockey     Moscow     1980.0  Hockey      hockey   PRINSLOO, Christine     Women   ZIM           W             Gold      1
#                                                                   ROBERTSON, Sonia        Women   ZIM           W             Gold      1
#                                                                   STEWART, Anthea Doreen  Women   ZIM           W             Gold      1
#                                                                   VOLK, Helen             Women   ZIM           W             Gold      1
#                                                                   WATSON, Linda Margaret  Women   ZIM           W             Gold      1
#   Name: count, Length: 15315, dtype: int64]]

# %%
sn.displot(data=olympic1, x="Medal", hue ="Medal",element="step")

# %%
sn.countplot(data=olympic1, x="Medal")
# Out:
# <Axes: xlabel='Medal', ylabel='count'>

# %%
olympic1["Athlete"].value_counts()
# Out:
# Athlete
# PHELPS, Michael                  16
# TORRES, Dara                     12
# THOMPSON, Jenny                  12
# NEMOV, Alexei                    12
# ANDRIANOV, Nikolay               12
#                                  ..
# KIM, Soon-Duk                     1
# KIRKWOOD, James William           1
# LEJEUNE, Elisabeth Anne Marie     1
# WOLFF, Ingrid Imelda              1
# LOPEZ, Mijain                     1
# Name: count, Length: 11337, dtype: int64

# %%
olympic1.head(5)
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
olympic1.dtypes
# Out:
# City             object
# Year            float64
# Sport            object
# Discipline       object
# Event            object
# Athlete          object
# Gender           object
# Country_Code     object
# Country          object
# Event_gender     object
# Medal            object
# dtype: object

# %%
olympic1 = olympic1.astype({"City": 'category', "Sport": 'category',"Athlete" : 'category',"Medal" : 'category'})

# %%
olympic1.dtypes
# Out:
# City            category
# Year             float64
# Sport           category
# Discipline        object
# Event             object
# Athlete         category
# Gender            object
# Country_Code      object
# Country           object
# Event_gender      object
# Medal           category
# dtype: object

# %%
olympic1 = olympic1.astype({"Country": 'category', "Discipline": 'category',"Gender" : 'category',"Event" : 'category'})

# %%
olympic1.dtypes
# Out:
# City            category
# Year             float64
# Sport           category
# Discipline      category
# Event           category
# Athlete         category
# Gender          category
# Country_Code      object
# Country         category
# Event_gender      object
# Medal           category
# dtype: object

# %%
olympic1[["Athlete","Medal"]]
# Out:
#                         Athlete   Medal
# 0               KÖHLER, Christa  Silver
# 1           KOSENKOV, Aleksandr  Bronze
# 2          BOGGS, Philip George    Gold
# 3      CAGNOTTO, Giorgio Franco  Silver
# 4        WILSON, Deborah Keplar  Bronze
# ...                         ...     ...
# 15428        GUENOT, Christophe  Bronze
# 15429       KVIRKELIA, Manuchar    Gold
# 15430          RAHIMOV, Vitaliy  Silver
# 15431            GUENOT, Steeve    Gold
# 15432             LOPEZ, Mijain    Gold
#
# [15316 rows x 2 columns]

# %%
olympic1.groupby(["Athlete"])["Medal"].count()
# Out:
# C:\Users\sileo\AppData\Local\Temp\ipykernel_4160\751580705.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   olympic1.groupby(["Athlete"])["Medal"].count()
# Athlete
# AAMODT, Ragnhild         1
# AARDENBURG, Willemien    1
# AARDEWIJN, Pepijn        1
# AARONES, Ann Kristin     1
# ABAJO, Jose Luis         1
#                         ..
# ZYCH, Boguslaw           1
# ZYKINA, Olesya           2
# ZÜHLKE, Steffen          1
# ZÜLOW, Andreas           1
# ÖRSTED, Hans-Henrik      1
# Name: Medal, Length: 11337, dtype: int64

# %%
olympic1.groupby(["Athlete"])["Medal"].count().max()
# Out:
# C:\Users\sileo\AppData\Local\Temp\ipykernel_4160\1186569819.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   olympic1.groupby(["Athlete"])["Medal"].count().max()
# 16

# %%
olympic1.groupby(["Athlete"])["Medal"].count().min()
# Out:
# C:\Users\sileo\AppData\Local\Temp\ipykernel_4160\2926735406.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   olympic1.groupby(["Athlete"])["Medal"].count().min()
# 1

# %%
Top5_players = olympic1.groupby(["Athlete"])["Medal"].count().nlargest(5)
Top5_players
# Out:
# C:\Users\sileo\AppData\Local\Temp\ipykernel_4160\3813119185.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Top5_players = olympic1.groupby(["Athlete"])["Medal"].count().nlargest(5)
# Athlete
# PHELPS, Michael       16
# ANDRIANOV, Nikolay    12
# FISCHER, Birgit       12
# NEMOV, Alexei         12
# THOMPSON, Jenny       12
# Name: Medal, dtype: int64

# %%
Top5value = Top5_players.values
Top5value
# Out:
# array([16, 12, 12, 12, 12], dtype=int64)

# %%
index = Top5_players.index
index
# Out:
# CategoricalIndex(['PHELPS, Michael', 'ANDRIANOV, Nikolay', 'FISCHER, Birgit',
#                   'NEMOV, Alexei', 'THOMPSON, Jenny'],
#                  categories=['AAMODT, Ragnhild', 'AARDENBURG, Willemien', 'AARDEWIJN, Pepijn', 'AARONES, Ann Kristin', ..., 'ZYKINA, Olesya', 'ZÜHLKE, Steffen', 'ZÜLOW, Andreas', 'ÖRSTED, Hans-Henrik'], ordered=False, dtype='category', name='Athlete')

# %%
top5Country = olympic1.groupby(["Country"])["Medal"].count().nlargest(5)
top5Country
# Out:
# C:\Users\sileo\AppData\Local\Temp\ipykernel_4160\3617252293.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   top5Country = olympic1.groupby(["Country"])["Medal"].count().nlargest(5)
# Country
# United States    1992
# Soviet Union     1021
# Australia         798
# Germany           691
# China             679
# Name: Medal, dtype: int64

# %%
import numpy as np
top5Country = olympic1.groupby(["Country"])["Medal"].count().nlargest(5)
fig,ax = plt.subplots(figsize=(6,6))
ax= plt.bar(top5Country, height= 3, width = 45)
topvalue = top5Country.values
topvalue
topindex = top5Country.index
topindex
ax =sn.barplot(data = olympic1,x= topindex,y=topvalue)
ax.bar_label(ax.containers[0])
# Out:
# C:\Users\sileo\AppData\Local\Temp\ipykernel_4160\4237375642.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[122], line 9
#       7 topindex = top5Country.index
#       8 topindex
# ----> 9 ax =sn.barplot(data = olympic1,x= topindex,y=topvalue)
#      10 ax.bar_label(ax.containers[0])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
#    2350 if ax is None:
#    2351     ax = plt.gca()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)
#      64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_core\data.py:251, in PlotData._assign_variables(self, data, variables)
#     245         val_cls = val.__class__.__name__
#     246         err = (
#     247             f"Length of {val_cls} vectors must match length of `data`"
#     248             f" when both are used, but `data` has length {len(data)}"
#     249             f" and the vector passed to `{key}` has length {len(val)}."
#     250         )
# --> 251         raise ValueError(err)
#     253 plot_data[key] = val
#     255 # Try to infer the original name using pandas-like metadata
#
# ValueError: Length of CategoricalIndex vectors must match length of `data` when both are used, but `data` has length 15316 and the vector passed to `x` has length 5.

# %%
sn.displot(data = olympic1, x=top5Country,hue =top5Country, bins =15)

# %%
olympic1.columns
# Out:
# Index(['City', 'Year', 'Sport', 'Discipline', 'Event', 'Athlete', 'Gender',
#        'Country_Code', 'Country', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
olympic1["City"].value_counts()
# Out:
# City
# Beijing        2042
# Sydney         2015
# Athens         1998
# Atlanta        1859
# Barcelona      1705
# Seoul          1546
# Los Angeles    1459
# Moscow         1386
# Montreal       1305
# Name: count, dtype: int64

# %%
olympic1["Year"].value_counts()
# Out:
# Year
# 2008.0    2042
# 2000.0    2015
# 2004.0    1998
# 1996.0    1859
# 1992.0    1705
# 1988.0    1546
# 1984.0    1459
# 1980.0    1386
# 1976.0    1305
# Name: count, dtype: int64

# %%
olympic1[['City', 'Year']].value_counts().reset_index(name='count')
# Out:
#           City    Year  count
# 0      Beijing  2008.0   2042
# 1       Sydney  2000.0   2015
# 2       Athens  2004.0   1998
# 3      Atlanta  1996.0   1859
# 4    Barcelona  1992.0   1705
# 5        Seoul  1988.0   1546
# 6  Los Angeles  1984.0   1459
# 7       Moscow  1980.0   1386
# 8     Montreal  1976.0   1305

# %%
p1 =olympic1["Gender"].value_counts()
p1
# Out:
# Gender
# Men      9387
# Women    5928
# Name: count, dtype: int64

# %%
p2 = olympic1["Sport"].value_counts().nlargest(5)
p2
# Out:
# Sport
# Aquatics      2210
# Athletics     1523
# Rowing        1377
# Hockey         816
# Gymnastics     783
# Name: count, dtype: int64

# %%
p2.index
# Out:
# CategoricalIndex(['Aquatics', 'Athletics', 'Rowing', 'Hockey', 'Gymnastics'], categories=['Aquatics', 'Archery', 'Athletics', 'Badminton', ..., 'Triathlon', 'Volleyball', 'Weightlifting', 'Wrestling'], ordered=False, dtype='category', name='Sport')

# %%
p3=olympic1["Sport"].value_counts().nsmallest(5)
p3
# Out:
# Sport
# Triathlon             18
# Taekwondo             80
# Modern Pentathlon     81
# Tennis               118
# Badminton            120
# Name: count, dtype: int64

# %%
p3.values
# Out:
# array([ 18,  80,  81, 118, 120], dtype=int64)

# %%
p3.index
# Out:
# CategoricalIndex(['Triathlon', 'Taekwondo', 'Modern Pentathlon', 'Tennis',
#                   'Badminton'],
#                  categories=['Aquatics', 'Archery', 'Athletics', 'Badminton', ..., 'Triathlon', 'Volleyball', 'Weightlifting', 'Wrestling'], ordered=False, dtype='category', name='Sport')

# %%
p4 =olympic1["Event"].value_counts().nlargest(5)
p4
# Out:
# Event
# hockey        816
# handball      780
# football      669
# volleyball    647
# basketball    646
# Name: count, dtype: int64

# %%
p5 =olympic1["Discipline"].value_counts().nlargest(10)
p5
# Out:
# Discipline
# Athletics      1523
# Swimming       1422
# Rowing         1377
# Hockey          816
# Handball        780
# Artistic G.     672
# Football        669
# Volleyball      647
# Basketball      646
# Fencing         606
# Name: count, dtype: int64

# %%
p6 = olympic1["Athlete"].value_counts().nlargest(10)
p6
# Out:
# Athlete
# PHELPS, Michael        16
# FISCHER, Birgit        12
# NEMOV, Alexei          12
# THOMPSON, Jenny        12
# TORRES, Dara           12
# ANDRIANOV, Nikolay     12
# COUGHLIN, Natalie      11
# BIONDI, Matthew        11
# DITYATIN, Aleksandr    10
# SCHERBO, Vitaly        10
# Name: count, dtype: int64

# %%
p6.index
# Out:
# CategoricalIndex(['PHELPS, Michael', 'FISCHER, Birgit', 'NEMOV, Alexei',
#                   'THOMPSON, Jenny', 'TORRES, Dara', 'ANDRIANOV, Nikolay',
#                   'COUGHLIN, Natalie', 'BIONDI, Matthew',
#                   'DITYATIN, Aleksandr', 'SCHERBO, Vitaly'],
#                  categories=['AAMODT, Ragnhild', 'AARDENBURG, Willemien', 'AARDEWIJN, Pepijn', 'AARONES, Ann Kristin', ..., 'ZYKINA, Olesya', 'ZÜHLKE, Steffen', 'ZÜLOW, Andreas', 'ÖRSTED, Hans-Henrik'], ordered=False, dtype='category', name='Athlete')

# %%
p7 = olympic1["City"].value_counts().nlargest(10)
p7
# Out:
# City
# Beijing        2042
# Sydney         2015
# Athens         1998
# Atlanta        1859
# Barcelona      1705
# Seoul          1546
# Los Angeles    1459
# Moscow         1386
# Montreal       1305
# Name: count, dtype: int64

# %%
p8 = olympic1["Country"].value_counts().nlargest(10)
p8
# Out:
# Country
# United States     1992
# Soviet Union      1021
# Australia          798
# Germany            691
# China              679
# Russia             638
# East Germany       626
# Italy              486
# Romania            482
# United Kingdom     467
# Name: count, dtype: int64

# %%
p8.index
# Out:
# CategoricalIndex(['United States', 'Soviet Union', 'Australia', 'Germany',
#                   'China', 'Russia', 'East Germany', 'Italy', 'Romania',
#                   'United Kingdom'],
#                  categories=['Afghanistan', 'Algeria', 'Argentina', 'Armenia', ..., 'West Germany', 'Yugoslavia', 'Zambia', 'Zimbabwe'], ordered=False, dtype='category', name='Country')

# %%
p9 = olympic1["Country"].value_counts().nsmallest(10)
p9
# Out:
# Country
# Virgin Islands*         1
# United Arab Emirates    1
# Uruguay                 1
# Afghanistan             1
# Tonga                   1
# Togo                    1
# Barbados                1
# Bermuda*                1
# Burundi                 1
# Cote d'Ivoire           1
# Name: count, dtype: int64

# %%
p10 = olympic1[["Country","Athlete"]].value_counts().nlargest(5)
p10
# Out:
# Country        Athlete
# United States  PHELPS, Michael       16
# Soviet Union   ANDRIANOV, Nikolay    12
# United States  THOMPSON, Jenny       12
#                TORRES, Dara          12
# Russia         NEMOV, Alexei         12
# Name: count, dtype: int64

# %%
p11 = olympic1[["Country","Year"]].value_counts().nlargest(5)
p11
# Out:
# Country        Year
# Soviet Union   1980.0    442
# United States  1984.0    333
#                2008.0    315
# Soviet Union   1988.0    294
#                1976.0    285
# Name: count, dtype: int64

# %%
#pip install jupyter_dashboards

# %%
f1 = olympic1[["City","Medal"]]
#fig =plt.figure(figsize=(6, 6))
fig,ax =plt.subplots(figsize=(9, 6))
ax=sn.countplot(data=f1,x="City",hue ="City")

# %%
f2 = olympic1[["Country","Medal"]]
#index = ['United States', 'Soviet Union', 'Australia', 'Germany','China', 'Russia', 'East Germany', 'Italy', 'Romania']
fig,ax =plt.subplots(figsize=(13, 6))
ax=sn.barplot(x=p8.index, y=p8.values)
ax=sn.countplot(data=f2,x=f2["Country"])
ax.bar_label(ax.containers[0])
plt.title(label ="Top 10 medal Winning Countries(1976 -2008)")
# Out:
# Text(0.5, 1.0, 'Top 10 medal Winning Countries(1976 -2008)')

# %%
f3=olympic1[["Sport","Medal"]]
f3
# Out:
#            Sport   Medal
# 0       Aquatics  Silver
# 1       Aquatics  Bronze
# 2       Aquatics    Gold
# 3       Aquatics  Silver
# 4       Aquatics  Bronze
# ...          ...     ...
# 15428  Wrestling  Bronze
# 15429  Wrestling    Gold
# 15430  Wrestling  Silver
# 15431  Wrestling    Gold
# 15432  Wrestling    Gold
#
# [15316 rows x 2 columns]

# %%
fig,ax =plt.subplots(figsize=(12, 4))
index =['Aquatics', 'Athletics', 'Rowing', 'Hockey', 'Gymnastics']
#ax=sn.countplot(data=f3,x="Sport",hue ="Sport")
ax=sn.barplot(x=index, y=p2.values,hue =index)
ax.bar_label(ax.containers[0])
plt.title(label ="Top 5 Sports")
# Out:
# Text(0.5, 1.0, 'Top 5 Sports')

# %%
f4=olympic1[["Athlete","Medal"]]
f4
# Out:
#                         Athlete   Medal
# 0               KÖHLER, Christa  Silver
# 1           KOSENKOV, Aleksandr  Bronze
# 2          BOGGS, Philip George    Gold
# 3      CAGNOTTO, Giorgio Franco  Silver
# 4        WILSON, Deborah Keplar  Bronze
# ...                         ...     ...
# 15428        GUENOT, Christophe  Bronze
# 15429       KVIRKELIA, Manuchar    Gold
# 15430          RAHIMOV, Vitaliy  Silver
# 15431            GUENOT, Steeve    Gold
# 15432             LOPEZ, Mijain    Gold
#
# [15316 rows x 2 columns]

# %%
fig,ax =plt.subplots(figsize=(16, 8))
index =['PHELPS, Michael', 'FISCHER, Birgit', 'NEMOV, Alexei','THOMPSON, Jenny', 'TORRES, Dara', 'ANDRIANOV, Nikolay',
        'COUGHLIN, Natalie', 'BIONDI, Matthew',
        'DITYATIN, Aleksandr', 'SCHERBO, Vitaly']
ax=sn.barplot(x=index, y=p6.values,hue =index)
ax.bar_label(ax.containers[0])
plt.title(label ="Top 10 medal winning Athlete(1976-2008)")
# Out:
# Text(0.5, 1.0, 'Top 10 medal winning Athlete(1976-2008)')

# %%
f3 =olympic1.groupby(["Sport"]).count().nlargest(10,columns="Medal")
fig,ax =plt.subplots(figsize=(16,8))
plt.plot(f3, marker="D")
# Out:
# C:\Users\sileo\AppData\Local\Temp\ipykernel_4160\2148084146.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   f3 =olympic1.groupby(["Sport"]).count().nlargest(10,columns="Medal")
# [<matplotlib.lines.Line2D at 0x217331f6210>,
#  <matplotlib.lines.Line2D at 0x217350c0950>,
#  <matplotlib.lines.Line2D at 0x21734b6c560>,
#  <matplotlib.lines.Line2D at 0x21734b6c050>,
#  <matplotlib.lines.Line2D at 0x21734b6f710>,
#  <matplotlib.lines.Line2D at 0x21711f81bb0>,
#  <matplotlib.lines.Line2D at 0x21711f82d50>,
#  <matplotlib.lines.Line2D at 0x21711f80d10>,
#  <matplotlib.lines.Line2D at 0x21711f80ad0>,
#  <matplotlib.lines.Line2D at 0x21735188500>]

# %%
import plotly.express as px
fig_poli = px.bar(olympic1, y='Medal',x='City', color ='City')
fig_poli.show()

# %%
fig_poli_bar = px.bar(olympic1, y='Medal',x='Sport', color ="Sport")
fig_poli_bar.show()

# %%
import plotly.express as px
fig = px.pie(olympic1, values='Medal', names='City')
fig.show()
